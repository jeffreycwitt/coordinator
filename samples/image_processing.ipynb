# %%
import numpy as np

# %%
# %matplotlib inline

# %%
from skimage.io import imread

# %%
import matplotlib.pyplot as plt

# %%
ls
# Out:
# Notebook1.ipynb         image_processing.pdf    lbppy.ipynb
# image_processing.ipynb  lbp.py                  rothwell1r.jpg

# %%
ls -lh rothwell1r.jpg
# Out:
# -rw-r--r--@ 1 jcwitt  980848918   547K Feb  4 14:06 rothwell1r.jpg

# %%
im = imread( 'rothwell1r.jpg')

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True )
ax1.imshow( im[900:1000,900:1000,0], cmap='gray')
ax2.imshow( im[900:1000,900:1000,1], cmap='gray')
ax3.imshow( im[900:1000,900:1000,2], cmap='gray')

# %%
plt.imshow( im )

# %%
row1 = im[1,:,0]

# %%
bw = plt??

# %%
bw = plt

# %%
row1.mean()
# Out:
# 33.746338215712385

# %%
im[:,:,0].mean(axis=0)
# Out:
# array([ 143.161 ,  140.1465,  138.1165, ...,   40.68  ,   40.8755,   41.049 ])

# %%
im[:,:,0].mean(axis=1)
# Out:
# array([ 33.73235686,  33.74633822,  33.7942743 , ...,  38.85952064,
#         38.80159787,  38.77829561])

# %%
meanrows = im[:,:,0].mean(axis=1)

# %%
meanrows.shape
# Out:
# (2000,)

# %%
plt.plot(meanrows)

# %%
# !jupyter nbconvert image_processing.ipynb --to pdf
# Out:
# [NbConvertApp] Converting notebook image_processing.ipynb to pdf
# [NbConvertApp] Support files will be in image_processing_files/
# [NbConvertApp] Making directory image_processing_files
# [NbConvertApp] Making directory image_processing_files
# [NbConvertApp] Making directory image_processing_files
# [NbConvertApp] Writing 23435 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 149390 bytes to image_processing.pdf

# %%
# !open image_processing.pdf

# %%
meanrows[1000]
# Out:
# 172.017310252996

# %%
for mean in meanrows:
    print(mean)
# Out:
# 33.7323568575
# 33.7463382157
# 33.7942743009
# 33.862183755
# 33.9427430093
# 34.0239680426
# 34.0332889481
# 34.0499334221
# 34.0046604527
# 34.1131824234
# 34.2616511318
# 34.4800266312
# 34.6744340879
# 34.82689747
# 34.9494007989
# 35.0452729694
# 36.6158455393
# 38.4280958722
# 40.9074567244
# 44.9394141145
# 48.8468708389
# 53.8868175766
# 58.6817576565
# 64.8501997337
# 72.2782956059
# 78.2876165113
# 83.792276964
# 89.7609853529
# 97.1498002663
# 105.951398136
# 110.168442077
# 111.950732357
# 115.690412783
# 118.54460719
# 123.810252996
# 126.959387483
# 129.593209055
# 131.771637816
# 133.466711052
# 135.676431425
# 137.392143808
# 138.659121172
# 139.706391478
# 140.963382157
# 142.181091877
# 143.121171771
# 145.627829561
# 147.635153129
# 149.319573901
# 151.340213049
# 153.040612517
# 153.278961385
# 153.719707057
# 153.927430093
# 153.94207723
# 153.190412783
# 152.332889481
# 151.721038615
# 150.820905459
# 150.091211718
# 149.39747004
# 148.982689747
# ...

# %%
newdata = []

# %%
for i in range(1,len(meanrows)):
    if meanrows[i] > meanrows[i-1] and meanrows[i] > meanrows[i+1]:
        newdata.append(i)

# %%
len(newdata)
# Out:
# 203

# %%
for i in data:
    print(i)
    im[i,:,:] = 0
# Out:
# 7
# 54
# 66
# 84
# 90
# 95
# 101
# 106
# 112
# 117
# 121
# 127
# 133
# 140
# 143
# 169
# 172
# 184
# 193
# 207
# 223
# 226
# 242
# 245
# 247
# 251
# 260
# 276
# 290
# 294
# 299
# 305
# 308
# 324
# 326
# 351
# 353
# 364
# 366
# 369
# 387
# 402
# 405
# 408
# 410
# 421
# 452
# 456
# 459
# 473
# 488
# 502
# 506
# 516
# 542
# 554
# 556
# 560
# 562
# 565
# 592
# 604
# 607
# 614
# 627
# 629
# 639
# 643
# 664
# 666
# 670
# 673
# 676
# 680
# 707
# 719
# 728
# 755
# 775
# 777
# 812
# 825
# 835
# 837
# 855
# 863
# 874
# 878
# 880
# 882
# 932
# 934
# 967
# 984
# 991
# 1022
# 1026
# 1044
# 1048
# 1078
# 1081
# 1097
# 1102
# 1129
# 1149
# 1152
# 1166
# 1181
# 1183
# 1200
# 1206
# 1262
# 1265
# 1273
# 1295
# 1313
# 1320
# 1349
# 1364
# 1370
# 1400
# 1422
# 1436
# 1439
# 1456
# 1461
# 1470
# 1474
# 1476
# 1485
# 1530
# 1533
# 1580
# 1582
# 1586
# 1605
# 1633
# 1637
# 1655
# 1666
# 1685
# 1694
# 1699
# 1704
# 1706
# 1709
# 1711
# 1714
# 1717
# 1720
# 1724
# 1730
# 1732
# 1735
# 1738
# 1744
# 1749
# ...

# %%
for i in range(0,len(im)):
    print(im[i,i,:])
# Out:
# [133 121  99]
# [121 108  89]
# [99 87 71]
# [81 71 59]
# [48 39 32]
# [44 36 33]
# [37 31 31]
# [0 0 0]
# [39 34 41]
# [38 33 40]
# [39 32 40]
# [38 31 39]
# [40 30 38]
# [41 32 37]
# [42 31 35]
# [43 32 36]
# [44 36 34]
# [42 37 34]
# [41 36 33]
# [39 35 34]
# [36 34 35]
# [35 35 37]
# [36 35 40]
# [37 36 42]
# [42 39 46]
# [75 70 74]
# [60 52 49]
# [50 38 26]
# [97 82 61]
# [104  88  55]
# [87 68 28]
# [67 49  3]
# [46 37  8]
# [33 23  0]
# [50 40 13]
# [127 117  92]
# [149 136 117]
# [112  99  82]
# [76 63 47]
# [76 62 49]
# [128 114 103]
# [32 19 10]
# [34 21 12]
# [32 22 13]
# [35 26 17]
# [44 37 27]
# [39 32 22]
# [48 41 31]
# [76 60 44]
# [71 55 39]
# [56 41 22]
# [68 53 34]
# [77 62 41]
# [97 82 59]
# [0 0 0]
# [112  96  71]
# [132 116  90]
# [143 126  98]
# [149 132 102]
# [143 127  94]
# [147 131  98]
# [153 134 101]
# [144 125  92]
# [141 122  89]
# [147 131  98]
# [148 132  99]
# [0 0 0]
# [164 148 115]
# [163 147 114]
# [163 147 114]
# [162 146 113]
# [157 141 108]
# ...

# %%
plt.imshow(im)
